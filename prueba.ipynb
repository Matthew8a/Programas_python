# %%
import pandas as pd

data_cars = pd.read_csv("/Users/ochoa/Proyecto7/vehicles_usp.csv")

# %%
data_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.2  51525 non-null  int64
#  1   Unnamed: 0.1  51525 non-null  int64
#  2   Unnamed: 0    51525 non-null  int64
#  3   price         51525 non-null  int64
#  4   model_year    47906 non-null  float64
#  5   model         51525 non-null  object
#  6   condition     51525 non-null  object
#  7   cylinders     46265 non-null  float64
#  8   fuel          51525 non-null  object
#  9   odometer      43633 non-null  float64
#  10  transmission  51525 non-null  object
#  11  type          51525 non-null  object
#  12  paint_color   42258 non-null  object
#  13  is_4wd        51525 non-null  bool
#  14  date_posted   51525 non-null  object
#  15  days_listed   51525 non-null  int64
# dtypes: bool(1), float64(3), int64(5), object(7)
# memory usage: 5.9+ MB

# %%
data_cars["model_year"] = data_cars["model_year"].astype("Int64")

# %%
data_cars["cylinders"] = data_cars["cylinders"].astype("Int64")

# %%
data_cars["odometer"] = data_cars["odometer"].astype("Int64")

# %%
data_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.2  51525 non-null  int64
#  1   Unnamed: 0.1  51525 non-null  int64
#  2   Unnamed: 0    51525 non-null  int64
#  3   price         51525 non-null  int64
#  4   model_year    47906 non-null  Int64
#  5   model         51525 non-null  object
#  6   condition     51525 non-null  object
#  7   cylinders     46265 non-null  Int64
#  8   fuel          51525 non-null  object
#  9   odometer      43633 non-null  Int64
#  10  transmission  51525 non-null  object
#  11  type          51525 non-null  object
#  12  paint_color   42258 non-null  object
#  13  is_4wd        51525 non-null  bool
#  14  date_posted   51525 non-null  object
#  15  days_listed   51525 non-null  int64
# dtypes: Int64(3), bool(1), int64(5), object(7)
# memory usage: 6.1+ MB

# %%
data_cars.sample(10)
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  price  model_year  \
# 4070           4070          4070        4070  29777        2016
# 21611         21611         21611       21611  24950        2013
# 19037         19037         19037       19037   7295        2016
# 1037           1037          1037        1037  12500        2018
# 26942         26942         26942       26942      1        2017
# 32763         32763         32763       32763   9495        2017
# 19456         19456         19456       19456   4250        2010
# 49910         49910         49910       49910   6900        2011
# 17908         17908         17908       17908   6000        2009
# 49146         49146         49146       49146  11500        <NA>
#
#                           model  condition  cylinders fuel  odometer  \
# 4070              dodge charger  excellent          8  gas     78700
# 21611                 ford f150  excellent       <NA>  gas    102101
# ...

# %%
data_cars = data_cars.drop(columns=["Unnamed: 0", "Unnamed: 0.1", "Unnamed: 0.2"])

# %%
data_cars.sample(10)
# Out:
#        price  model_year                     model  condition  cylinders fuel  \
# 2622    7995        2011                honda cr-v       good          4  gas
# 32997   5950        2007              honda accord  excellent          4  gas
# 24233  28400        2017  ford mustang gt coupe 2d       good          8  gas
# 4933   10900        2013               ford escape   like new          4  gas
# 46952  11000        2011           chevrolet tahoe       good          8  gas
# 28087   6500        2007  chevrolet silverado 1500       good          8  gas
# 28022   3000        2000              ford mustang  excellent          8  gas
# 9305    6900        2008               ford escape       good          6  gas
# 29136   7000        2004             toyota tundra       good          8  gas
# 43654   6900        2008               kia sorento       good          6  gas
#
#        odometer transmission   type paint_color  is_4wd date_posted  \
# ...

# %%
data_cars.to_csv("/Users/ochoa/Proyecto7/vehicles_us2.csv", index=False)

# %%
df = pd.read_csv("/Users/ochoa/Proyecto7/vehicles_us2.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    47906 non-null  float64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     46265 non-null  float64
#  5   fuel          51525 non-null  object
#  6   odometer      43633 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   42258 non-null  object
#  10  is_4wd        51525 non-null  bool
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: bool(1), float64(3), int64(2), object(7)
# memory usage: 4.8+ MB
