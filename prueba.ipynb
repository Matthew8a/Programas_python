# %%
import pandas as pd

data_cars = pd.read_csv("/Users/ochoa/Proyecto7/vehicles_us.csv")

# %%
data_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    47906 non-null  Int64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     46265 non-null  float64
#  5   fuel          51525 non-null  object
#  6   odometer      43633 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   42258 non-null  object
#  10  is_4wd        25572 non-null  float64
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: Int64(1), float64(3), int64(2), object(7)
# memory usage: 5.2+ MB

# %%
data_cars.sample(10)
# Out:
#        price  model_year                     model  condition  cylinders fuel  \
# 571     7900      2015.0          volkswagen jetta   like new        4.0  gas
# 39587  11888      2010.0  chevrolet silverado 1500       good        8.0  gas
# 50299   9495         NaN              honda accord  excellent        4.0  gas
# 8820    4450      2007.0              honda accord  excellent        4.0  gas
# 28899   9950      2010.0       jeep grand cherokee  excellent        6.0  gas
# 26419  13900      2006.0             toyota tacoma       good        6.0  gas
# 42755  10000      2004.0             jeep wrangler  excellent        4.0  gas
# 13206   4800      2005.0       jeep grand cherokee  excellent        8.0  gas
# 49312  13988      2008.0             jeep wrangler       good        6.0  gas
# 31450   6900      2015.0              chrysler 200  excellent        4.0  gas
#
#        odometer transmission     type paint_color  is_4wd date_posted  \
# ...

# %%
data_cars["cylinders"] = data_cars["cylinders"].astype("Int64")

# %%
data_cars["is_4wd"] = data_cars["is_4wd"].astype(bool)

# %%
data_cars.sample(10)
# Out:
#        price  model_year                model  condition  cylinders    fuel  \
# 41165   4900        2001  chevrolet silverado       fair          8  diesel
# 33224  13990        2005        toyota tundra       good       <NA>     gas
# 42779   8000        2005           gmc sierra       good          8     gas
# 21378  19995        2016        honda odyssey  excellent          6     gas
# 50482   4995        2005           honda cr-v       good          4     gas
# 37186  15997        2014        toyota sienna   like new          6     gas
# 17692   5500        1987   chevrolet corvette       fair          8     gas
# 20470  10990        2016       honda civic lx  excellent          4     gas
# 30381  11950        2013         honda accord  excellent          4     gas
# 32270   1500        2006          ford taurus       good          6     gas
#
#        odometer transmission         type paint_color  is_4wd date_posted  \
# ...

# %%
data_cars.to_csv("/Users/ochoa/Proyecto7/vehicles_usp.csv")

# %%
data_cars["model_year"] = data_cars["model_year"].astype("Int64")
